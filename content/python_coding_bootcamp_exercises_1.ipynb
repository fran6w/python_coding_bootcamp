# %% [markdown]
# # Exercise A
# Create a function called "add" that
#
#
# *   Takes two values as arguments
# *   Sum thoses two values
# *   Return The result
#
# Then use it to show the result of  10 + 5

# %% [markdown]
# # Exercise B
#
# Create a function called "print_list" that
#
# * Takes one list as an argument
# * Print the list element by element using a loop
#
# Then use is to print the elements of a list.

# %% [markdown]
# # Exercise C
# Create a function called "print_even" that
#
# * Takes one list of integers as an argument
# * Print the list element by element using a loop, only if the element is even
#
# Then use is to print the even elements of a list.

# %% [markdown]
# # Exercise D
#
# Create a function called "mean" that
#
# * Takes one list of numbers as an argument
# * Compute the mean of the list
# * Return the mean of the list
#
# Then use is to print the mean of a list.

# %% [markdown]
# # Exercise E
# Create a function called "variance" that
#
# * Takes one list of numbers as an argument
# * Compute the variance of the list using the mean function that you created
# * Return the variance of the list
#
# Then use is to print the variance of a list.

# %% [markdown]
# # Exercise F
# Create a function named sum_list :
#
# - Which takes as input a list of numbers
# - Returns the sum of the values
#
#
# The function needs to check if the argument is a list and if not raise a TypeError
#
# The Error must be caught by the except and print an error message
#
#
# ```python
# def something(param):
#     try:
#         if something_wrong_with_type:
#             raise TypeError()
#         # Instructions if everything is fine
#         print("Ok it works.")
#     except
#         print("something is wrong with the type of the argument")
#
# ```

# %% [markdown]
# # Exercise G
#
# Create a function named word_counts:
# *   Which takes as input a file name
# *   Returns a dictionary with the number of words in the file (you can use the split() method to get all words in the text).
#
# Then use this function with the following text https://www.gutenberg.org/files/11/11-0.txt

# %% [markdown]
# # Exercise H
#
# Create a class Dataset that:
#
#
#
# *   Is instanciated with a list of numbers
# *   Implements 3 methods:
#     * sum() returns the sum of all values in the list
#     * mean() returns the mean of all values in the list
#     * variance() returns the variance of all values in the list
#
# Then use this class to give the sum, mean and variance of a list.
